# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.listdir()
# Out:
# ['AD-020718_01-SP.xlsx',
#  'gui',
#  'file1.csv',
#  '.test_runs.py.swp',
#  '__pycache__',
#  'test_runs.py',
#  'rodeo.py',
#  '.ipynb_checkpoints',
#  'read_pot.py',
#  'potentiostat',
#  'Untitled.ipynb',
#  '.read_pot.py.swp',
#  'test_scenario.txt',
#  'data.csv',
#  'data_cv.csv',
#  'AD-020718_01-SP.TXT',
#  '+',
#  'docs.txt',
#  '.test_scenario.txt.swp',
#  'data_chronoamp.csv']

# %%
names = ['t(s)', 'V(v)', 'I(mamp)', 'quietValue', 
         'quietTime', 'duration', 'current_range', 
         'test_name', 'potentiostat_id', 'electrode', ]
data_chrono = pd.read_csv('data_chronoamp.csv', names = names)

# %%
data_chrono.head()
# Out:
#    t(s)  V(v)  I(mamp)  quietValue  quietTime  duration current_range  \
# 0   1.0  0.05  1.57918        0.05          0     60000         100uA
# 1   2.0  0.05  1.52604        0.05          0     60000         100uA
# 2   3.0  0.05  1.54695        0.05          0     60000         100uA
# 3   4.0  0.05  1.55383        0.05          0     60000         100uA
# 4   5.0  0.05  1.53365        0.05          0     60000         100uA
#
#    test_name  potentiostat_id electrode
# 0  chronoamp                2    dummy2
# 1  chronoamp                2    dummy2
# 2  chronoamp                2    dummy2
# 3  chronoamp                2    dummy2
# 4  chronoamp                2    dummy2

# %%
names = ['t(s)', 'V(v)', 'I(mamp)', 'quietValue', 
         'quietTime', 'amplitude', 'offset', 'period',
        'numCycles', 'shift','test_name', 'potentiostat_id',
        'electrode']

data_cyclic = pd.read_csv('data_cv.csv', names=names)

# %%
data_cyclic.head()
# Out:
#    t(s)  V(v)  I(mamp)  quietValue  quietTime  amplitude  offset  period  \
# 0   0.1 -0.19 -3.30401           0          0        0.6     0.4   24000
# 1   0.2 -0.18 -3.11975           0          0        0.6     0.4   24000
# 2   0.3 -0.17 -2.86412           0          0        0.6     0.4   24000
# 3   0.4 -0.16 -2.66503           0          0        0.6     0.4   24000
# 4   0.5 -0.15 -2.47001           0          0        0.6     0.4   24000
#
#    numCycles  shift test_name  potentiostat_id electrode
# 0         10    0.0    cyclic                2    dummy2
# 1         10    0.0    cyclic                2    dummy2
# 2         10    0.0    cyclic                2    dummy2
# 3         10    0.0    cyclic                2    dummy2
# 4         10    0.0    cyclic                2    dummy2

# %%
data_chrono.groupby('potentiostat_id')[['I(mamp)']].plot()
# Out:
# potentiostat_id
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
data_chrono.groupby('potentiostat_id')[['V(v)']].plot()
# Out:
# potentiostat_id
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
data_cyclic.groupby('potentiostat_id')[['I(mamp)']].plot()
# Out:
# potentiostat_id
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
data_cyclic.groupby('potentiostat_id')[['V(v)']].plot()
# Out:
# potentiostat_id
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
plt.plot(data_cyclic['V(v)'], data_cyclic['I(mamp)'])
